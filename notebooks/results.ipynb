# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, '..')
from utils import plot_stroke

# %% [markdown]
# # Results

# %% [markdown]
# This is what you should modify:

# %%
from models.kurt import generate_unconditionally, generate_conditionally, recognize_stroke

# %% [markdown]
# Please, don't modify anything below.
#
# ### Unconditional generation:

# %%
stroke = generate_unconditionally()
plot_stroke(stroke)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-9151c8275422> in <module>()
# ----> 1 stroke = generate_unconditionally()
#       2 plot_stroke(stroke)
#
# ~/Documents/etc/lyrebird/lyrebird-egg-master/models/kurt.py in generate_unconditionally(random_seed, model, epoch, length)
#     682     with tf.Graph().as_default() as graph:
#     683         with tf.Session().as_default() as session:
# --> 684             unconditional = Unconditional(mdldir=path.join(MDLDEF, model), epoch=epoch)
#     685             stroke, = unconditional.synth(length)
#     686
#
# ~/Documents/etc/lyrebird/lyrebird-egg-master/models/kurt.py in __init__(self, **kwargs)
#     115 class Unconditional(ModelBase):
#     116     def __init__(self, **kwargs):
# --> 117         ModelBase.__init__(self, 'Unconditional', **kwargs)
#     118
#     119     def _create(self, **kwargs):
#
# ~/Documents/etc/lyrebird/lyrebird-egg-master/models/kurt.py in __init__(self, name, **kwargs)
#      46                 mdldir = kwargs.pop('mdldir')
#      47                 epoch = kwargs.pop('epoch', None)
# ---> 48                 self._restore(mdldir, epoch)
#      49             except KeyError:
#      50                 raise ValueError('mdldir argument not provided')
#
# ~/Documents/etc/lyrebird/lyrebird-egg-master/models/kurt.py in _restore(self, mdldir, epoch)
#      58         """
#      59         g = tf.get_default_graph()
# ---> 60         meta = tf.train.import_meta_graph(path.join(mdldir, '_.meta'))
#      61         if epoch is not None:
#      62             with open(path.join(mdldir, 'checkpoint'), 'w') as f:
#
# ~/miniconda3/envs/lyrebird/lib/python3.6/site-packages/tensorflow/python/training/saver.py in import_meta_graph(meta_graph_or_file, clear_devices, import_scope, **kwargs)
#    1929                        "execution is enabled.")
#    1930   if not isinstance(meta_graph_or_file, meta_graph_pb2.MetaGraphDef):
# -> 1931     meta_graph_def = meta_graph.read_meta_graph_file(meta_graph_or_file)
#    1932   else:
#    1933     meta_graph_def = meta_graph_or_file
#
# ~/miniconda3/envs/lyrebird/lib/python3.6/site-packages/tensorflow/python/framework/meta_graph.py in read_meta_graph_file(filename)
#     631   meta_graph_def = meta_graph_pb2.MetaGraphDef()
#     632   if not file_io.file_exists(filename):
# --> 633     raise IOError("File %s does not exist." % filename)
#     634   # First try to read it as a binary file.
#     635   file_content = file_io.FileIO(filename, "rb").read()
#
# OSError: File /home/kurt/Documents/etc/lyrebird/lyrebird-egg-master/mdldef/u/_.meta does not exist.

# %% [markdown]
# ### Conditional generation:

# %%
stroke = generate_conditionally(text='welcome to lyrebird')
plot_stroke(stroke)
# Out:
# INFO:tensorflow:Restoring parameters from /home/kurt/Documents/etc/lyrebird/lyrebird-egg-master/mdldef/c/_-4

# %% [markdown]
# ### Handwriting recognition:

# %%
text = recognize_stroke(stroke)
print text
# Out:
# welcome to lyrebird
